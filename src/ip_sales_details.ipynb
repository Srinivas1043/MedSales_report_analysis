# %%
import pandas as pd 
import numpy as np

# %%
data_for_sales_details = pd.read_excel('../data/processed/Ip_Sales_Details.xlsx')

# %%
data_for_sales_details.head()
# Out:
#    Unnamed: 0  registrationno  ipid Patient Name    billNo  billamount  \
# 0           0             101  1001          PN1  BILL0001       24631
# 1           1             102  1002          PN2  BILL0002      111836
# 2           2             103  1003          PN3  BILL0003     1291502
# 3           3             104  1004          PN4  BILL0004      165998
# 4           4             105  1005          PN5  BILL0005      184397
#
#    discount  netamount               doctorname               Specialisation  \
# 0       0.0    24631.0                      EMO  TRAUMA & EMERGENCY MEDICINE
# 1       0.0   111836.0  IYER VIVEK VENKATARAMAN                    NEUROLOGY
# 2   81368.0  1210134.0            THIRUPPATHI.K                  PULMONOLOGY
# 3       0.0   165998.0         CLEMENT JOSEPH J                 ORTHOPAEDICS
# 4   12000.0   172397.0          MUTHU VEERAMANI                      UROLOGY
#
# ...

# %%
data_for_sales_details = data_for_sales_details.drop(['Unnamed: 0'],axis=1)

# %%
data_for_sales_details.head()
# Out:
#    registrationno  ipid Patient Name    billNo  billamount  discount  \
# 0             101  1001          PN1  BILL0001       24631       0.0
# 1             102  1002          PN2  BILL0002      111836       0.0
# 2             103  1003          PN3  BILL0003     1291502   81368.0
# 3             104  1004          PN4  BILL0004      165998       0.0
# 4             105  1005          PN5  BILL0005      184397   12000.0
#
#    netamount               doctorname               Specialisation  \
# 0    24631.0                      EMO  TRAUMA & EMERGENCY MEDICINE
# 1   111836.0  IYER VIVEK VENKATARAMAN                    NEUROLOGY
# 2  1210134.0            THIRUPPATHI.K                  PULMONOLOGY
# 3   165998.0         CLEMENT JOSEPH J                 ORTHOPAEDICS
# 4   172397.0          MUTHU VEERAMANI                      UROLOGY
#
#         admitdatetime       dischargedatetime       Area Country  PackageFees  \
# ...

# %%
data_for_sales_details['PackageFees']= data_for_sales_details['PackageFees'].fillna(0)

# %%
data_for_sales_details.head()
# Out:
#    registrationno  ipid Patient Name    billNo  billamount  discount  \
# 0             101  1001          PN1  BILL0001       24631       0.0
# 1             102  1002          PN2  BILL0002      111836       0.0
# 2             103  1003          PN3  BILL0003     1291502   81368.0
# 3             104  1004          PN4  BILL0004      165998       0.0
# 4             105  1005          PN5  BILL0005      184397   12000.0
#
#    netamount               doctorname               Specialisation  \
# 0    24631.0                      EMO  TRAUMA & EMERGENCY MEDICINE
# 1   111836.0  IYER VIVEK VENKATARAMAN                    NEUROLOGY
# 2  1210134.0            THIRUPPATHI.K                  PULMONOLOGY
# 3   165998.0         CLEMENT JOSEPH J                 ORTHOPAEDICS
# 4   172397.0          MUTHU VEERAMANI                      UROLOGY
#
#         admitdatetime       dischargedatetime       Area Country  PackageFees  \
# ...

# %%
data_for_sales_details.to_excel('../data/final/Ip_Sales_Details_Final.xlsx')
