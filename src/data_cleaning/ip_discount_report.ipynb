# %%
import pandas as pd

# %%
df_discount_report =pd.read_excel('../../data/processed/Ip_Discount_Report.xlsx')

# %%
df_discount_report.head()
# Out:
#    Unnamed: 0    BILLNO BILL TYPE           BILL DATE  IPID PATIENT NAME  \
# 0           0  BILL0001    Credit 2021-09-17 12:28:09  1001          PN1
# 1           1  BILL0002    Credit 2021-09-29 10:49:07  1002          PN2
# 2           2  BILL0003    Credit 2021-11-12 11:29:50  1003          PN3
# 3           3  BILL0004    Credit 2021-07-26 13:12:38  1004          PN4
# 4           4  BILL0005    Credit 2021-08-09 15:53:10  1005          PN5
#
#    BILLAMOUNT  DEPOSIT  RECEIPT  DISCOUNT  REFUND  TOTAL AMOUNT  \
# 0       78321    20000     4875       0.0   14660       38786.0
# 1      210272   150000    50137       0.0  180444     -170309.0
# 2      349015    20000    21700       0.0       0      302151.0
# 3       39272     5000     3600       0.0    2147       28525.0
# 4      680736    50000   166387   14350.0   21610      428389.0
#
#                        INSURANCE NAME
# 0  ADHITYA BIRLA HEALTH INSURANCE LTD
# 1  ADHITYA BIRLA HEALTH INSURANCE LTD
# ...

# %%
df_discount_report = df_discount_report.drop(['Unnamed: 0'],axis=1)

# %%
df_discount_report.head()
# Out:
#      BILLNO BILL TYPE           BILL DATE  IPID PATIENT NAME  BILLAMOUNT  \
# 0  BILL0001    Credit 2021-09-17 12:28:09  1001          PN1       78321
# 1  BILL0002    Credit 2021-09-29 10:49:07  1002          PN2      210272
# 2  BILL0003    Credit 2021-11-12 11:29:50  1003          PN3      349015
# 3  BILL0004    Credit 2021-07-26 13:12:38  1004          PN4       39272
# 4  BILL0005    Credit 2021-08-09 15:53:10  1005          PN5      680736
#
#    DEPOSIT  RECEIPT  DISCOUNT  REFUND  TOTAL AMOUNT  \
# 0    20000     4875       0.0   14660       38786.0
# 1   150000    50137       0.0  180444     -170309.0
# 2    20000    21700       0.0       0      302151.0
# 3     5000     3600       0.0    2147       28525.0
# 4    50000   166387   14350.0   21610      428389.0
#
#                        INSURANCE NAME
# 0  ADHITYA BIRLA HEALTH INSURANCE LTD
# 1  ADHITYA BIRLA HEALTH INSURANCE LTD
# 2  ADHITYA BIRLA HEALTH INSURANCE LTD
# 3    ADITYA BIRLA HEALTH INSURANCE CO
# ...

# %%
df_discount_report.to_excel('../data/final/Ip_Discount_Report_Final.xlsx')
