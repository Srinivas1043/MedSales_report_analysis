# %%
import pandas as pd

# %%
df_sales_report = pd.read_excel('../data\processed\Ip_Sales_Report.xlsx')

# %%
df_sales_report.head()
# Out:
#    Unnamed: 0       REG  NO DOCTOR NAME PATIENT NAME   BILL NO  BILL AMOUNT  \
# 0           0  TR30006              ALL          PN1  BILL0001         1900
# 1           1  TR30008              ALL          PN2  BILL0002          500
# 2           2  TR30007              ALL          PN3  BILL0003         1200
# 3           3  TR30011              ALL          PN4  BILL0004          900
# 4           4  TR30010              ALL          PN5  BILL0005          750
#
#    DISCOUNT  REFUND AMOUNT COMPANY SPECIALISATION            datetime   billid
# 0       950            450    SELF  NEURO SURGERY 2021-07-03 08:36:32  1109012
# 1         0            450    SELF  NEURO SURGERY 2021-07-03 08:53:40  1109022
# 2         0            450    SELF  NEURO SURGERY 2021-07-03 08:50:21  1109020
# 3         0            450    SELF  NEURO SURGERY 2021-07-03 09:11:04  1109037
# 4         0            450    SELF  NEURO SURGERY 2021-07-03 09:05:59  1109034

# %%
df_sales_report = df_sales_report.drop(['Unnamed: 0'],axis =1)

# %%
df_sales_report.head()
# Out:
#         REG  NO DOCTOR NAME PATIENT NAME   BILL NO  BILL AMOUNT  DISCOUNT  \
# 0  TR30006              ALL          PN1  BILL0001         1900       950
# 1  TR30008              ALL          PN2  BILL0002          500         0
# 2  TR30007              ALL          PN3  BILL0003         1200         0
# 3  TR30011              ALL          PN4  BILL0004          900         0
# 4  TR30010              ALL          PN5  BILL0005          750         0
#
#    REFUND AMOUNT COMPANY SPECIALISATION            datetime   billid
# 0            450    SELF  NEURO SURGERY 2021-07-03 08:36:32  1109012
# 1            450    SELF  NEURO SURGERY 2021-07-03 08:53:40  1109022
# 2            450    SELF  NEURO SURGERY 2021-07-03 08:50:21  1109020
# 3            450    SELF  NEURO SURGERY 2021-07-03 09:11:04  1109037
# 4            450    SELF  NEURO SURGERY 2021-07-03 09:05:59  1109034

# %%
df_sales_report.to_excel('../data/final/Ip_Sales_Report_Final.xlsx')
